# %% [markdown]
# <a href="https://colab.research.google.com/github/k-jnu/Google-Colab/blob/main/0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SCS")
# Out:
# SCS
